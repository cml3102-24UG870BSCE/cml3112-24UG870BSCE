# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
import sys
assert sys.version_info.major == 3, "Notebook expects Python 3"

# %% [markdown]
# The cause of the error: "The code used assert to demand that the major version must be 2 yet Google Colab runs on Python 3 hence the AssertionError showed up"
#
# Fix: "I repaired it by changing the assertion to expect 3"
