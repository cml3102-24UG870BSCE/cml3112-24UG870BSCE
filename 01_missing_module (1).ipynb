# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
#import course_package_not_installed

# %% [markdown]
# The cause of the error: "The code failed with a ModuleNotFoundError because it tried to import the package (course_package_not_installed) that was not intalled in the Colab environment"
#
# Fix: "I repaired the error by commenting out the line"
