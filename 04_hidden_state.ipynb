# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
readings = 12
readings = readings + 5
#readings = 12
print(readings)  # expected fresh-run result: 17
# Out:
# 17

# %% [markdown]
# The cause: "The code ran without error but gave a wrong answer because it reassigned the readings variable back to 12 after adding 5"
#
# Fix: "I repaired it by commenting out the duplicate assignment"
